# %%
##Web Scraping
- See HW1 beautiful soup for how to do it
- ethical implications of web scraping: be aware of accuracy and source of data you're scraping, are you violating terms of service?

##Types of data
- simple = 1 piece of information
- atomic = many
- numeric, boolean, strings: always have to ask yourself what kind of data you're recording
- categorical vs numerical data
- for numerical: discrete vs continuous data type
    
##Data Storgae
- typically tabular with columns representing the type of data (attribute, features) and rows the specific observations (record)

##Example of Hubway
- each row has a unique id
- data organized by increasing date vertically
- trip data on the left and customer data on the right. Note: multiple trips per customer possible
    
##Common issues with data
- missing values: how to fill in? filter vs dropping rows (biases) vs dropping column (consider looking into why this column was so empty)
- wrong values: how can we detect and correct? 
- Messy format
- data may not be usable

#Messy Data 
- not tabular format > need to put it into tabular format first
- three variables are: day, time of day and number of deliveries
- 9 observations total = rows

##Basics of sampling
- Collect data. Biases in samples:
    - selection bias
    - nonresponse bias
- Can calculate:
    - Sample mean: center of the distribution of the data. There is always uncertainty.
    - Sample median: mean is severily affected by outliers, the median is not. Think about which one makes more sense to use given your research question e.g. avg salary of Harvard class that incl. Bill gates > median better
    - skeweness
    
##Computational times
- mean: O(n)
- median: at most O(n) or O(nlogn)
- range: max - min
- variance: how much on avg the sample values deviate from the mean
- std deviation is in the same units as the initial data set which is why we use it instead of variance
    
##Categorical variables
- mean and median make no sense. Modes make more sense

##DATA EXPLORATION: VISUALIZATION
- Anscombe's data: summary statistics don't tell the whole picture
- show: dist, relationsip, compostion, comparison
- hist: viz how 1-dimensional data is dist across certain values. Want the right level of granularity to get enough info but not too much
    - multiple histograms on the same plot to compare how different sub-groups compare in terms of distribution
- pie chart: frowned upon b/c humans better at comparing lengths than angles
- scatter plot: way to viz relationship between multi variables.
- stacked area graph: viz the composition of group as it changes over time
- boxplot: compare quant variable across several groups (simplified)
    
##EXAMPLE: THE DATA SCIENCE PROCESS
- ask interesting question
- get data
- explore data
- model data
- communicate/viz
